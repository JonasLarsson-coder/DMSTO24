# %%
import matplotlib.pyplot as plt
import numpy as np
import math


x_vals = np.linspace(0, 20, 20)
print (x_vals)
y_vals = [math.sqrt(i) for i in x_vals]
plt.plot(x_vals, y_vals)
print(y_vals)
plt.title("Graf över  NÅGOT")
plt.xlabel("x") 
plt.ylabel("y") 
plt.show()
# Out:
# [ 0.          1.05263158  2.10526316  3.15789474  4.21052632  5.26315789
#   6.31578947  7.36842105  8.42105263  9.47368421 10.52631579 11.57894737
#  12.63157895 13.68421053 14.73684211 15.78947368 16.84210526 17.89473684
#  18.94736842 20.        ]
# [0.0, 1.025978352085154, 1.4509525002200232, 1.7770466332772772, 2.051956704170308, 2.2941573387056176, 2.513123449750173, 2.7144835701531846, 2.9019050004400464, 3.077935056255462, 3.2444284226152504, 3.4027852368936027, 3.5540932665545544, 3.6992175559590694, 3.8388594797495723, 3.9735970711951314, 4.103913408340616, 4.230217115244236, 4.35285750066007, 4.47213595499958]
